# %% [markdown]
# <a href="https://colab.research.google.com/github/SebasMP054/Colab/blob/colab/Guhub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime
import pytz # Para manejar zonas horarias

# 1. Pedir el nombre al usuario (Entrada - Input)
nombre = input("¡Hola! ¿Cuál es tu nombre? ")

# 2. Obtener la fecha y hora actual en la zona horaria de Perú
# Define la zona horaria de Lima, Perú
zona_horaria_lima = pytz.timezone('America/Lima')
# Obtiene la hora actual en esa zona horaria
ahora_en_lima = datetime.datetime.now(zona_horaria_lima)

# 3. Formatear la fecha y hora para una mejor presentación
fecha_formateada = ahora_en_lima.strftime("%d/%m/%Y") # Día/Mes/Año
hora_formateada = ahora_en_lima.strftime("%H:%M:%S") # Hora:Minuto:Segundo

# 4. Mostrar el saludo y la información (Salida - Print)
print(f"¡Mucho gusto, {nombre}!")
print(f"Hoy es {fecha_formateada} y la hora actual en Perú es {hora_formateada}.")
# Out:
# ¡Hola! ¿Cuál es tu nombre? Marce
# ¡Mucho gusto, Marce!
# Hoy es 13/06/2025 y la hora actual en Perú es 14:43:13.
